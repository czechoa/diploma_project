# %%
import numpy as np

from dash_app.backend.db_dictonary import load_datasets
from dash_app.backend.utils.object.dataset import DataSet

# %load_ext autoreload
# %autoreload 2

db_dict = load_datasets()
# Out:
# No config specified, defaulting to: polemo2-official/all_text
# Found cached dataset polemo2-official (/home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70)
#   0%|          | 0/3 [00:00<?, ?it/s]
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-c021d5bf561e290f.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-db7cac934caeab99.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-a7aeb121be9e7ac5.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-82a9bc9103cc9119.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-ed63e9eeae52d510.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-d6556817f650587c.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-1805bece2eb0ade7.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-975f18021b7fb2de.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-768582d4fd8a229f.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-b8c37cb82b4ad359.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-2e3b3c8e840e4a6f.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-f513e9a9cee36243.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-1aea38367616e34b.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-a1eece9a898dd725.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-ba7165313bf5fb3e.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-153aaacbe710499f.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-f16386c1d7f8524c.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-1fd110502656fe98.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-ceb780ffeb43adaf.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-6395f5707ac452ac.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-c82e4df7068aa8f5.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-70cbffa42dd180e2.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-95b36a960c5f63c7.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/clarin-pl___polemo2-official/all_text/0.0.0/2b75fdbe5def97538e81fb120f8752744b50729a4ce09bd75132bfc863a2fd70/cache-592a5558e87ecec6.arrow
# Using custom data configuration default
# Found cached dataset allegro_reviews (/home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b)
#   0%|          | 0/3 [00:00<?, ?it/s]
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-bfadc55624fd0ebe.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-a93c1a7500be791e.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-20b62f03335d7e81.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-6a2f4c8f002bd2c7.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-2307a1461f69c6dc.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-b2be880fe3fcdb0e.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-e23e86deccff5070.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-4674f3826701ae19.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-0492042fa43e2071.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-c8b9c70129d2defc.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-2a046258fb2d0185.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-9be733fbc44b8f22.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-7038953f1cedd400.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-d69b50cbd6f9b597.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-a3c1ea4c11abdbac.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-0ce9af58a92dd205.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-f366c1b197813d8d.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-79865ee3ea1a2187.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-b2691cd826d2db84.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-9329fc295cf6b7a3.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-da834fcb2c9d3c17.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-78cc6d86c229c095.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-0cf98c0418af587c.arrow
# Loading cached processed dataset at /home/andrzej/.cache/huggingface/datasets/allegro_reviews/default/1.1.0/d0fd6bf6f7f8f2c8faed7ecf9d295c991eac403ca516d3d3593061a913c0476b/cache-1661e8d807bf1f94.arrow

# %%
merged_data = db_dict['połączone'].data
train = merged_data['train'].to_pandas()
validation = merged_data['validation'].to_pandas()

# %%
train
# Out:
#                                                     text  rating  liczba_zdań  \
# 0      Jako do ceny dobra. Przyssawka mogłaby być lep...     3.0            4
# 1      Na słuchawkę czekałam spory czas a po zadzwoni...     1.0            5
# 2      Czajnik na pierwszy rzut oka wygląda ok, ale n...     1.0            3
# 3      Bardzo fajny czajnik, na pewno nie gorszy od m...     4.0            5
# 4      Pomysł na produkt (uchwyt na kierownicę) bardz...     2.0            5
# ...                                                  ...     ...          ...
# 15593  Hotel z bardzo dobrym jedzeniem , jak już się ...     NaN            5
# 15594  Zazwyczaj wystawiam mało opinii , ponieważ bra...     NaN           14
# 15595  Trudno dać wiarę , że na wyciągnięcie ręki od ...     NaN            7
# 15596  Był em u tego lekarza , ponieważ mój lekarz pr...     NaN            7
# 15597  Hotel na 5 , rodzinny pobyt all inclusive nie ...     NaN            9
#
#        liczba_słów  liczba_znaków ocena_tekst  \
# 0               35            280   neutralne
# 1               50            499   negatywne
# 2               43            395   negatywne
# 3               37            330   pozytywne
# 4               51            436   negatywne
# ...            ...            ...         ...
# 15593           32            289   pozytywne
# 15594          127           1180   pozytywne
# 15595           50            488   negatywne
# 15596           59            635   negatywne
# 15597           69            566   pozytywne
#
#                                              token_tekst  \
# 0      [cena, dobro, przyssawka, móc by, dobry, 2, mi...
# 1      [słuchawka, czekać być, spór, czas, zadzwonien...
# 2      [czajnik, pierwszy, rzut, oko, wyglądać, nie, ...
# 3      [fajny, czajnik, pewno, nie, gorszy, markowy, ...
# 4      [pomysł, produkt, uchwyt, kierownica, dobry, w...
# ...                                                  ...
# 15593  [hotel, dobry, jedzenie, udać, dotrzeć, dać, z...
# 15594  [zazwyczaj, wystawiać, opinia, brakować, czas,...
# 15595  [trudno, dać, wiara, wyciągnięt, ręka, stolica...
# 15596  [lekarz, lekarz, prowadzący, nieobecny, doktor...
# 15597  [hotel, 5, rodzinny, pobyt, all, inclusive, ni...
#
#                             token_tekst_with_autocorrect  \
# 0      [cena, dobro, przyssawka, móc by, lepsz, 2, mi...
# 1      [słuchawka, czekać być, spór, czas, zadzwonien...
# 2      [czajnik, pierwszy, rzut, oko, wyglądać, nie, ...
# 3      [fajny, czajnik, pewno, nie, gorszy, markowy, ...
# 4      [pomysł, produkt, uchwyt, kierownica, dobry, w...
# ...                                                  ...
# 15593  [hotel, dobry, jedzenie, udać, dotrzeć, dać, z...
# 15594  [zazwyczaj, wystawiać, opinia, brakować, czas,...
# 15595  [trudno, dać, wiara, wyciągnięt, ręka, stolica...
# 15596  [lekarz, lekarz, prowadzący, nieobecny, doktor...
# 15597  [hotel, 5, rodzinny, pobyt, all, inclusive, ni...
#
#                                            token_adj_adv  \
# 0                                        [dobry, prosty]
# 1      [sam, najszybszym, tak, gdzie, bardzo, potrzeb...
# 2      [pierwszy, ciągły, nieprzyjemnie, wygotowywać,...
# 3      [bardzo, fajny, pewno, gorszy, trochę, wygodni...
# 4      [bardzo, dobry, słaby, 1, sporadyczć, dolny, p...
# ...                                                  ...
# 15593  [bardzo, dobry, idealny, położyć, bardzo, malo...
# 15594  [zazwyczaj, głęboko, winien, sam, 2, szczerze,...
# 15595  [trudno, rzekomo, negatywny, zamieszczć, zgodn...
# 15596  [prowadzący, nieobecny, płatkowy, koszykowy, p...
# 15597  [rodzinny, bardzo, udany, cichy, spokojny, bar...
#
#                                      subset_of_two_words  \
# 0      [cena dobro, dobro przyssawka, przyssawka móc ...
# 1      [słuchawka czekać być, czekać być spór, spór c...
# 2      [czajnik pierwszy, pierwszy rzut, rzut oko, ok...
# 3      [fajny czajnik, czajnik pewno, pewno nie, nie ...
# 4      [pomysł produkt, produkt uchwyt, uchwyt kierow...
# ...                                                  ...
# 15593  [hotel dobry, dobry jedzenie, jedzenie udać, u...
# 15594  [zazwyczaj wystawiać, wystawiać opinia, opinia...
# 15595  [trudno dać, dać wiara, wiara wyciągnięt, wyci...
# 15596  [lekarz lekarz, lekarz prowadzący, prowadzący ...
# 15597  [hotel 5, 5 rodzinny, rodzinny pobyt, pobyt al...
#
#                                    subset_of_three_words  target  \
# 0      [cena dobro przyssawka, dobro przyssawka móc b...     NaN
# 1      [słuchawka czekać być spór, czekać być spór cz...     NaN
# 2      [czajnik pierwszy rzut, pierwszy rzut oko, rzu...     NaN
# 3      [fajny czajnik pewno, czajnik pewno nie, pewno...     NaN
# 4      [pomysł produkt uchwyt, produkt uchwyt kierown...     NaN
# ...                                                  ...     ...
# 15593  [hotel dobry jedzenie, dobry jedzenie udać, je...     2.0
# 15594  [zazwyczaj wystawiać opinia, wystawiać opinia ...     2.0
# 15595  [trudno dać wiara, dać wiara wyciągnięt, wiara...     1.0
# 15596  [lekarz lekarz prowadzący, lekarz prowadzący n...     1.0
# 15597  [hotel 5 rodzinny, 5 rodzinny pobyt, rodzinny ...     2.0
#
#        __index_level_0__
# 0                      0
# 1                      1
# 2                      2
# 3                      3
# 4                      4
# ...                  ...
# 15593               6568
# 15594               6569
# 15595               6570
# 15596               6571
# 15597               6572
#
# [15598 rows x 13 columns]

# %%
from unidecode import unidecode

mapper_target_value = {
    'negatywne': 0,
    'neutralne': 1,
    'pozytywne': 2,
}


def get_unicode_text(col):
    texts_org = train[col].str.join(" ")
    texts = texts_org.apply(unidecode)

    texts_val = validation[col].str.join(" ")

    return texts, texts_val


target = list(map(lambda x: mapper_target_value[x], train['ocena_tekst']))
target_val = list(map(lambda x: mapper_target_value[x], validation['ocena_tekst']))

texts, texts_val = get_unicode_text('token_tekst')

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline


def find_the_best_model_parameter(texts, target):
    text_clf = Pipeline(
        [
            ("vect", CountVectorizer(strip_accents='ascii')),
            ("tfidf", TfidfTransformer()),
            ("clf", LogisticRegression(max_iter=1000,n_jobs=-1,multi_class='ovr')),
        ]
    )
    parameters = {
    'vect__ngram_range': [(1, 1), (1, 2)],
    'vect__min_df': [1, 2],
    'tfidf__use_idf': (True, False),
    'clf__C': (1,10,20)

    }

    gs_clf = GridSearchCV(text_clf, parameters, cv=5, n_jobs=-1)
    gs_clf = gs_clf.fit(texts, target)
    print(gs_clf.best_score_)
    for param_name in sorted(parameters.keys()):
        print("%s: %r" % (param_name, gs_clf.best_params_[param_name]))
find_the_best_model_parameter(texts,target)
# Out:
# 0.7443936666091202
# clf__C: 10
# tfidf__use_idf: True
# vect__min_df: 2
# vect__ngram_range: (1, 2)

# %%
from sklearn import metrics
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score, f1_score


def plot_and_print_score_model(target_val, y_pred):
    conf_matrix = confusion_matrix(y_true=target_val, y_pred=y_pred)

    fig, ax = plt.subplots(figsize=(5, 5))
    ax.matshow(conf_matrix, cmap=plt.cm.Oranges, alpha=0.3)
    for i in range(conf_matrix.shape[0]):
        for j in range(conf_matrix.shape[1]):
            ax.text(x=j, y=i, s=conf_matrix[i, j], va='center', ha='center', size='xx-large')

    plt.xlabel('Predictions', fontsize=18)
    plt.ylabel('Actuals', fontsize=18)
    plt.title('Confusion Matrix', fontsize=18)
    plt.show()

    # print('Precision: %.3f' % precision_score(target_val, y_pred))  # Precision Score = TP / (FP + TP)
    # print('Recall: %.3f' % recall_score(target_val, y_pred))  # Recall Score = TP / (FN + TP)
    # print('Accuracy: %.3f' % accuracy_score(target_val, y_pred))  # Accuracy Score = (TP + TN)/ (TP + FN + TN + FP)
    # print('F1 Score: %.3f' % f1_score(target_val,
    #                                   y_pred))  # F1 Score = 2* Precision Score * Recall Score/ (Precision Score + Recall Score/)
    print(metrics.classification_report(target_val, y_pred, target_names=mapper_target_value.keys()))

# %%
text_clf = Pipeline(
    [
        ("vect", CountVectorizer(strip_accents='ascii', min_df=2,ngram_range=(1,2))),
        ("tfidf", TfidfTransformer(use_idf=True)),
        ("clf", LogisticRegression(C=10,max_iter=1000,n_jobs=-1,multi_class='ovr',)),
    ]
)
text_clf.fit(texts,target)

y_pred = text_clf.predict(texts_val)
plot_and_print_score_model(target_val, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#    negatywne       0.79      0.84      0.81       631
#    neutralne       0.70      0.48      0.57       420
#    pozytywne       0.78      0.87      0.82       740
#
#     accuracy                           0.77      1791
#    macro avg       0.76      0.73      0.74      1791
# weighted avg       0.76      0.77      0.76      1791

# %%
texts, texts_val = get_unicode_text('token_tekst_without_noun')
find_the_best_model_parameter(texts, target)
# Out:
# 0.7313802089755922
# clf__C: 20
# tfidf__use_idf: True
# vect__min_df: 1
# vect__ngram_range: (1, 2)

# %%
text_clf = Pipeline(
    [
        ("vect", CountVectorizer(strip_accents='ascii', min_df=2, ngram_range=(1, 2))),
        ("tfidf", TfidfTransformer(use_idf=True)),
        ("clf", LogisticRegression(C=20, max_iter=1000, n_jobs=-1, multi_class='ovr')),
    ]
)
text_clf.fit(texts, target)

y_pred = text_clf.predict(texts_val)
plot_and_print_score_model(target_val, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#    negatywne       0.76      0.82      0.79       631
#    neutralne       0.62      0.46      0.53       420
#    pozytywne       0.78      0.84      0.81       740
#
#     accuracy                           0.74      1791
#    macro avg       0.72      0.71      0.71      1791
# weighted avg       0.74      0.74      0.74      1791

# %%
texts, texts_val = get_unicode_text('token_tekst_with_autocorrect')
find_the_best_model_parameter(texts, target)
# Out:
# /home/andrzej/PycharmProjects/diploma_project/venv/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# 0.7459964567867742
# clf__C: 10
# tfidf__use_idf: True
# vect__min_df: 2
# vect__ngram_range: (1, 2)

# %%
text_clf = Pipeline(
    [
        ("vect", CountVectorizer(strip_accents='ascii', min_df=2,ngram_range=(1,2))),
        ("tfidf", TfidfTransformer(use_idf=True)),
        ("clf", LogisticRegression(C=10,max_iter=1000,n_jobs=-1,multi_class='ovr',)),
    ]
)
text_clf.fit(texts,target)

y_pred = text_clf.predict(texts_val)
plot_and_print_score_model(target_val, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#    negatywne       0.79      0.85      0.82       631
#    neutralne       0.69      0.49      0.57       420
#    pozytywne       0.79      0.86      0.82       740
#
#     accuracy                           0.77      1791
#    macro avg       0.75      0.73      0.74      1791
# weighted avg       0.76      0.77      0.76      1791

# %%
text_clf = Pipeline(
    [
        ("vect", CountVectorizer(strip_accents='ascii', min_df=2,ngram_range=(1,2))),
        ("tfidf", TfidfTransformer(use_idf=True)),
        ("clf", LogisticRegression(C=10,max_iter=1000,n_jobs=-1,multi_class='multinomial',)),
    ]
)
text_clf.fit(texts,target)

y_pred = text_clf.predict(texts_val)
plot_and_print_score_model(target_val, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#    negatywne       0.79      0.84      0.81       631
#    neutralne       0.66      0.51      0.58       420
#    pozytywne       0.79      0.85      0.82       740
#
#     accuracy                           0.77      1791
#    macro avg       0.75      0.73      0.74      1791
# weighted avg       0.76      0.77      0.76      1791

# %%
token_text = train['token_tekst']
token_text_with_autocorrect = train['token_tekst_with_autocorrect']
text = train['text']

# %%
import numpy as np
[(x,y,review)for token, autocorrect, review in zip(token_text.values,token_text_with_autocorrect.values,text)  for x,y in zip(token,autocorrect) if x != y]
#[~(token_text[0] == token_text_with_autocorrect[0])]
# Out:
# [('dobry',
#   'lepsz',
#   'Jako do ceny dobra. Przyssawka mogłaby być lepsza. Po 2 miesiącach użytkowania musiałem nóżkę z przyssawką rozkręcić i przyssawkę podkleić bo guma zaczęła pękać od strony mocowania do uchwytu (uchwyt zaczął się po prostu trząść bo zrobił się luz). Mechanizm mocowania telefonu póki co (3 miesiące użytkowania) działa bez zarzutu.'),
#  ('podkleić',
#   'odkleić',
#   'Jako do ceny dobra. Przyssawka mogłaby być lepsza. Po 2 miesiącach użytkowania musiałem nóżkę z przyssawką rozkręcić i przyssawkę podkleić bo guma zaczęła pękać od strony mocowania do uchwytu (uchwyt zaczął się po prostu trząść bo zrobił się luz). Mechanizm mocowania telefonu póki co (3 miesiące użytkowania) działa bez zarzutu.'),
#  ('nastawić być',
#   'nastawić',
#   'Na słuchawkę czekałam spory czas a po zadzwonieniu okazało się ,że paczka im się zawieruszyła i w ten sam dzień mieli wysłać najszybszym kurierem i mimo to i tak czekałam znowu gdzie bardzo mi była potrzebna. Do tego niby bateria trzyma długo gdzie tak nie jest i słuchawka się rozłącza . Dostałam ponownie wiadomość o tym ,że znowu dostanę te samą paczkę po wiadomości do nich ,że to pomyłka Pan odpisał mi,że nie bo to gratis no to się nastawiłam ,że gratis i ,że opłacona za to ,że tyle musiałam czekać .Tym razem przyjeżdża listonosz i mówi paczka do opłaty .Paczka poszła na pocztę i tam sobie leży ;) !'),
#  ('.tym',
#   'raz',
#   'Na słuchawkę czekałam spory czas a po zadzwonieniu okazało się ,że paczka im się zawieruszyła i w ten sam dzień mieli wysłać najszybszym kurierem i mimo to i tak czekałam znowu gdzie bardzo mi była potrzebna. Do tego niby bateria trzyma długo gdzie tak nie jest i słuchawka się rozłącza . Dostałam ponownie wiadomość o tym ,że znowu dostanę te samą paczkę po wiadomości do nich ,że to pomyłka Pan odpisał mi,że nie bo to gratis no to się nastawiłam ,że gratis i ,że opłacona za to ,że tyle musiałam czekać .Tym razem przyjeżdża listonosz i mówi paczka do opłaty .Paczka poszła na pocztę i tam sobie leży ;) !'),
#  ('raz',
#   'przyjeżdżać',
#   'Na słuchawkę czekałam spory czas a po zadzwonieniu okazało się ,że paczka im się zawieruszyła i w ten sam dzień mieli wysłać najszybszym kurierem i mimo to i tak czekałam znowu gdzie bardzo mi była potrzebna. Do tego niby bateria trzyma długo gdzie tak nie jest i słuchawka się rozłącza . Dostałam ponownie wiadomość o tym ,że znowu dostanę te samą paczkę po wiadomości do nich ,że to pomyłka Pan odpisał mi,że nie bo to gratis no to się nastawiłam ,że gratis i ,że opłacona za to ,że tyle musiałam czekać .Tym razem przyjeżdża listonosz i mówi paczka do opłaty .Paczka poszła na pocztę i tam sobie leży ;) !'),
#  ('przyjeżdżać',
#   'listonosz',
#   'Na słuchawkę czekałam spory czas a po zadzwonieniu okazało się ,że paczka im się zawieruszyła i w ten sam dzień mieli wysłać najszybszym kurierem i mimo to i tak czekałam znowu gdzie bardzo mi była potrzebna. Do tego niby bateria trzyma długo gdzie tak nie jest i słuchawka się rozłącza . Dostałam ponownie wiadomość o tym ,że znowu dostanę te samą paczkę po wiadomości do nich ,że to pomyłka Pan odpisał mi,że nie bo to gratis no to się nastawiłam ,że gratis i ,że opłacona za to ,że tyle musiałam czekać .Tym razem przyjeżdża listonosz i mówi paczka do opłaty .Paczka poszła na pocztę i tam sobie leży ;) !'),
#  ('listonosz',
#   'mówić',
#   'Na słuchawkę czekałam spory czas a po zadzwonieniu okazało się ,że paczka im się zawieruszyła i w ten sam dzień mieli wysłać najszybszym kurierem i mimo to i tak czekałam znowu gdzie bardzo mi była potrzebna. Do tego niby bateria trzyma długo gdzie tak nie jest i słuchawka się rozłącza . Dostałam ponownie wiadomość o tym ,że znowu dostanę te samą paczkę po wiadomości do nich ,że to pomyłka Pan odpisał mi,że nie bo to gratis no to się nastawiłam ,że gratis i ,że opłacona za to ,że tyle musiałam czekać .Tym razem przyjeżdża listonosz i mówi paczka do opłaty .Paczka poszła na pocztę i tam sobie leży ;) !'),
#  ('mówić',
#   'paczka',
#   'Na słuchawkę czekałam spory czas a po zadzwonieniu okazało się ,że paczka im się zawieruszyła i w ten sam dzień mieli wysłać najszybszym kurierem i mimo to i tak czekałam znowu gdzie bardzo mi była potrzebna. Do tego niby bateria trzyma długo gdzie tak nie jest i słuchawka się rozłącza . Dostałam ponownie wiadomość o tym ,że znowu dostanę te samą paczkę po wiadomości do nich ,że to pomyłka Pan odpisał mi,że nie bo to gratis no to się nastawiłam ,że gratis i ,że opłacona za to ,że tyle musiałam czekać .Tym razem przyjeżdża listonosz i mówi paczka do opłaty .Paczka poszła na pocztę i tam sobie leży ;) !'),
#  ('paczka',
#   'opłata',
#   'Na słuchawkę czekałam spory czas a po zadzwonieniu okazało się ,że paczka im się zawieruszyła i w ten sam dzień mieli wysłać najszybszym kurierem i mimo to i tak czekałam znowu gdzie bardzo mi była potrzebna. Do tego niby bateria trzyma długo gdzie tak nie jest i słuchawka się rozłącza . Dostałam ponownie wiadomość o tym ,że znowu dostanę te samą paczkę po wiadomości do nich ,że to pomyłka Pan odpisał mi,że nie bo to gratis no to się nastawiłam ,że gratis i ,że opłacona za to ,że tyle musiałam czekać .Tym razem przyjeżdża listonosz i mówi paczka do opłaty .Paczka poszła na pocztę i tam sobie leży ;) !'),
#  ('opłata',
#   'paczka',
#   'Na słuchawkę czekałam spory czas a po zadzwonieniu okazało się ,że paczka im się zawieruszyła i w ten sam dzień mieli wysłać najszybszym kurierem i mimo to i tak czekałam znowu gdzie bardzo mi była potrzebna. Do tego niby bateria trzyma długo gdzie tak nie jest i słuchawka się rozłącza . Dostałam ponownie wiadomość o tym ,że znowu dostanę te samą paczkę po wiadomości do nich ,że to pomyłka Pan odpisał mi,że nie bo to gratis no to się nastawiłam ,że gratis i ,że opłacona za to ,że tyle musiałam czekać .Tym razem przyjeżdża listonosz i mówi paczka do opłaty .Paczka poszła na pocztę i tam sobie leży ;) !'),
#  ('.paczka',
#   'pójść',
#   'Na słuchawkę czekałam spory czas a po zadzwonieniu okazało się ,że paczka im się zawieruszyła i w ten sam dzień mieli wysłać najszybszym kurierem i mimo to i tak czekałam znowu gdzie bardzo mi była potrzebna. Do tego niby bateria trzyma długo gdzie tak nie jest i słuchawka się rozłącza . Dostałam ponownie wiadomość o tym ,że znowu dostanę te samą paczkę po wiadomości do nich ,że to pomyłka Pan odpisał mi,że nie bo to gratis no to się nastawiłam ,że gratis i ,że opłacona za to ,że tyle musiałam czekać .Tym razem przyjeżdża listonosz i mówi paczka do opłaty .Paczka poszła na pocztę i tam sobie leży ;) !'),
#  ('pójść',
#   'poczta',
#   'Na słuchawkę czekałam spory czas a po zadzwonieniu okazało się ,że paczka im się zawieruszyła i w ten sam dzień mieli wysłać najszybszym kurierem i mimo to i tak czekałam znowu gdzie bardzo mi była potrzebna. Do tego niby bateria trzyma długo gdzie tak nie jest i słuchawka się rozłącza . Dostałam ponownie wiadomość o tym ,że znowu dostanę te samą paczkę po wiadomości do nich ,że to pomyłka Pan odpisał mi,że nie bo to gratis no to się nastawiłam ,że gratis i ,że opłacona za to ,że tyle musiałam czekać .Tym razem przyjeżdża listonosz i mówi paczka do opłaty .Paczka poszła na pocztę i tam sobie leży ;) !'),
#  ('poczta',
#   'leżeć',
#   'Na słuchawkę czekałam spory czas a po zadzwonieniu okazało się ,że paczka im się zawieruszyła i w ten sam dzień mieli wysłać najszybszym kurierem i mimo to i tak czekałam znowu gdzie bardzo mi była potrzebna. Do tego niby bateria trzyma długo gdzie tak nie jest i słuchawka się rozłącza . Dostałam ponownie wiadomość o tym ,że znowu dostanę te samą paczkę po wiadomości do nich ,że to pomyłka Pan odpisał mi,że nie bo to gratis no to się nastawiłam ,że gratis i ,że opłacona za to ,że tyle musiałam czekać .Tym razem przyjeżdża listonosz i mówi paczka do opłaty .Paczka poszła na pocztę i tam sobie leży ;) !'),
#  ('pachnąć',
#   'pachnie',
#   'Czajnik na pierwszy rzut oka wygląda ok, ale nie polecam!!! Woda pomimo ciągłego gotowania nieprzyjemnie pachnie, czajnik był wygotowywany wielokrotnie w kwasku cytrynowym, sodzie, occie i nic nie pomaga zniwelować nieprzyjemnego zapachu wody. Po tygodniu wygotowywania czajnika, bo woda z niego jest nie do picia zauważyłam, że cieknie gdzieś od spodu. W porównaniu z moim starym czajnikiem mam też wrażenie, że czas oczekiwania na zagotowaną wodę jest dłuższy.'),
#  ('soda',
#   'lodzie',
#   'Czajnik na pierwszy rzut oka wygląda ok, ale nie polecam!!! Woda pomimo ciągłego gotowania nieprzyjemnie pachnie, czajnik był wygotowywany wielokrotnie w kwasku cytrynowym, sodzie, occie i nic nie pomaga zniwelować nieprzyjemnego zapachu wody. Po tygodniu wygotowywania czajnika, bo woda z niego jest nie do picia zauważyłam, że cieknie gdzieś od spodu. W porównaniu z moim starym czajnikiem mam też wrażenie, że czas oczekiwania na zagotowaną wodę jest dłuższy.'),
#  ('czajnik',
#   'czujniek',
#   'Czajnik na pierwszy rzut oka wygląda ok, ale nie polecam!!! Woda pomimo ciągłego gotowania nieprzyjemnie pachnie, czajnik był wygotowywany wielokrotnie w kwasku cytrynowym, sodzie, occie i nic nie pomaga zniwelować nieprzyjemnego zapachu wody. Po tygodniu wygotowywania czajnika, bo woda z niego jest nie do picia zauważyłam, że cieknie gdzieś od spodu. W porównaniu z moim starym czajnikiem mam też wrażenie, że czas oczekiwania na zagotowaną wodę jest dłuższy.'),
#  ('wrażenie',
#   'wrażena',
#   'Czajnik na pierwszy rzut oka wygląda ok, ale nie polecam!!! Woda pomimo ciągłego gotowania nieprzyjemnie pachnie, czajnik był wygotowywany wielokrotnie w kwasku cytrynowym, sodzie, occie i nic nie pomaga zniwelować nieprzyjemnego zapachu wody. Po tygodniu wygotowywania czajnika, bo woda z niego jest nie do picia zauważyłam, że cieknie gdzieś od spodu. W porównaniu z moim starym czajnikiem mam też wrażenie, że czas oczekiwania na zagotowaną wodę jest dłuższy.'),
#  ('zagotowany',
#   'zanotowany',
#   'Czajnik na pierwszy rzut oka wygląda ok, ale nie polecam!!! Woda pomimo ciągłego gotowania nieprzyjemnie pachnie, czajnik był wygotowywany wielokrotnie w kwasku cytrynowym, sodzie, occie i nic nie pomaga zniwelować nieprzyjemnego zapachu wody. Po tygodniu wygotowywania czajnika, bo woda z niego jest nie do picia zauważyłam, że cieknie gdzieś od spodu. W porównaniu z moim starym czajnikiem mam też wrażenie, że czas oczekiwania na zagotowaną wodę jest dłuższy.'),
#  ('długi',
#   'dłuższy',
#   'Czajnik na pierwszy rzut oka wygląda ok, ale nie polecam!!! Woda pomimo ciągłego gotowania nieprzyjemnie pachnie, czajnik był wygotowywany wielokrotnie w kwasku cytrynowym, sodzie, occie i nic nie pomaga zniwelować nieprzyjemnego zapachu wody. Po tygodniu wygotowywania czajnika, bo woda z niego jest nie do picia zauważyłam, że cieknie gdzieś od spodu. W porównaniu z moim starym czajnikiem mam też wrażenie, że czas oczekiwania na zagotowaną wodę jest dłuższy.'),
#  ('tefal',
#   'team',
#   'Bardzo fajny czajnik, na pewno nie gorszy od markowych jak Tefal czy Bosch. Trochę na początku czuć plastikiem, to mija. Ma wygodnie umieszczone przyciski - na górze, a nie na dole, co się przydaje przy myciu (nie zalewa się przycisku) i szerokie czytelne szkiełko z miarką podświetlane od środka. Wlot też szeroki, można nawet włożyć rękę przy czyszczeniu. Chińczycy dobrze odrobili lekcje.'),
#  ('czyszczeć',
#   'czyszczeniu',
#   'Bardzo fajny czajnik, na pewno nie gorszy od markowych jak Tefal czy Bosch. Trochę na początku czuć plastikiem, to mija. Ma wygodnie umieszczone przyciski - na górze, a nie na dole, co się przydaje przy myciu (nie zalewa się przycisku) i szerokie czytelne szkiełko z miarką podświetlane od środka. Wlot też szeroki, można nawet włożyć rękę przy czyszczeniu. Chińczycy dobrze odrobili lekcje.'),
#  ('słaby',
#   'słabe',
#   'Pomysł na produkt (uchwyt na kierownicę) bardzo dobry natomiast wykonanie uchwytu słabe. Po około 1-2 miesiącach sporadycznego użytkowania dolna częśc uchwytu po prostu się odrywa od reszty i uchwyt nadaje się do wyrzucenia. Dolna część uchwytu oderwała się w obu sztukach zakupionego przedmiotu. Wystarczy po prostu produkować uchwyt z lepszej jakości materiałów i nie będzie tego problemu. Na ten moment mogę jedynie polecić tym, którzy za jakiś czas (1-2 miesiące) chcą kupować następną sztukę tego produktu.'),
#  ('częśc',
#   'część',
#   'Pomysł na produkt (uchwyt na kierownicę) bardzo dobry natomiast wykonanie uchwytu słabe. Po około 1-2 miesiącach sporadycznego użytkowania dolna częśc uchwytu po prostu się odrywa od reszty i uchwyt nadaje się do wyrzucenia. Dolna część uchwytu oderwała się w obu sztukach zakupionego przedmiotu. Wystarczy po prostu produkować uchwyt z lepszej jakości materiałów i nie będzie tego problemu. Na ten moment mogę jedynie polecić tym, którzy za jakiś czas (1-2 miesiące) chcą kupować następną sztukę tego produktu.'),
#  ('wyrzucenie',
#   'wyrzucć',
#   'Pomysł na produkt (uchwyt na kierownicę) bardzo dobry natomiast wykonanie uchwytu słabe. Po około 1-2 miesiącach sporadycznego użytkowania dolna częśc uchwytu po prostu się odrywa od reszty i uchwyt nadaje się do wyrzucenia. Dolna część uchwytu oderwała się w obu sztukach zakupionego przedmiotu. Wystarczy po prostu produkować uchwyt z lepszej jakości materiałów i nie będzie tego problemu. Na ten moment mogę jedynie polecić tym, którzy za jakiś czas (1-2 miesiące) chcą kupować następną sztukę tego produktu.'),
#  ('platronics',
#   'platoć',
#   'To już drugi Platronics w moim życiu (niestety poprzedni został zagubiony po około 8 latach używania :( ) i również się na tym modelu nie zawiodłem. Bardzo długi czas działania na baterii, Wygodny kształt (dla nie ale to zależy od każdego ucha). Jakość dźwięku do rozmowy bardzo dobra - do słuchania muzyki - słabo chociaż można bo słuchawka może działać w trybie multimediów (odtwarzać nie tylko rozmowy ale i to co idzie na głośnik zewnętrzny np nawigację, muzykę itp. ). Dla mnie to doskonały produkt w niskiej cenie - bardzo polecam.'),
#  ('używania',
#   'używanie',
#   'To już drugi Platronics w moim życiu (niestety poprzedni został zagubiony po około 8 latach używania :( ) i również się na tym modelu nie zawiodłem. Bardzo długi czas działania na baterii, Wygodny kształt (dla nie ale to zależy od każdego ucha). Jakość dźwięku do rozmowy bardzo dobra - do słuchania muzyki - słabo chociaż można bo słuchawka może działać w trybie multimediów (odtwarzać nie tylko rozmowy ale i to co idzie na głośnik zewnętrzny np nawigację, muzykę itp. ). Dla mnie to doskonały produkt w niskiej cenie - bardzo polecam.'),
#  ('ucho',
#   'uch',
#   'To już drugi Platronics w moim życiu (niestety poprzedni został zagubiony po około 8 latach używania :( ) i również się na tym modelu nie zawiodłem. Bardzo długi czas działania na baterii, Wygodny kształt (dla nie ale to zależy od każdego ucha). Jakość dźwięku do rozmowy bardzo dobra - do słuchania muzyki - słabo chociaż można bo słuchawka może działać w trybie multimediów (odtwarzać nie tylko rozmowy ale i to co idzie na głośnik zewnętrzny np nawigację, muzykę itp. ). Dla mnie to doskonały produkt w niskiej cenie - bardzo polecam.'),
#  ('i tym podobne',
#   'itp',
#   'To już drugi Platronics w moim życiu (niestety poprzedni został zagubiony po około 8 latach używania :( ) i również się na tym modelu nie zawiodłem. Bardzo długi czas działania na baterii, Wygodny kształt (dla nie ale to zależy od każdego ucha). Jakość dźwięku do rozmowy bardzo dobra - do słuchania muzyki - słabo chociaż można bo słuchawka może działać w trybie multimediów (odtwarzać nie tylko rozmowy ale i to co idzie na głośnik zewnętrzny np nawigację, muzykę itp. ). Dla mnie to doskonały produkt w niskiej cenie - bardzo polecam.'),
#  ('cichy',
#   'cicha',
#   'zmywarka po kilku miesiącach działa be zarzutu, cicha, łatwa w utrzymaniu czystości, plus dodatkowa szuflada na sztućce, minus dolny kosz lekki przy załadunku części przedniej przechyla się, ale to kwestia przyzwyczajenia się do wkładania naczyń w pierwszej kolejności do tyłu, jeżeli mamy brudne garnki, bo tylko tam jest miejsce. Ogólnie pozytyw'),
#  ('szufladać',
#   'szuflada',
#   'zmywarka po kilku miesiącach działa be zarzutu, cicha, łatwa w utrzymaniu czystości, plus dodatkowa szuflada na sztućce, minus dolny kosz lekki przy załadunku części przedniej przechyla się, ale to kwestia przyzwyczajenia się do wkładania naczyń w pierwszej kolejności do tyłu, jeżeli mamy brudne garnki, bo tylko tam jest miejsce. Ogólnie pozytyw'),
#  ('stick',
#   'stiuk',
#   'Super fajny selfie stick. Rączka stojakowa rozkłada się banalnie a składa się na zasadzie magnesu który jest od dołu w pałeczkach. Sam pilot działa bez problemu wszystko w jednym i selfie i stojak. Nic już nie stoi na przeszkodzie aby robić podczas wycieczek fajne fotki z każdej perspektywy dzięki stojakowi :) Polecam'),
#  ('stojakowy',
#   'stożkowy',
#   'Super fajny selfie stick. Rączka stojakowa rozkłada się banalnie a składa się na zasadzie magnesu który jest od dołu w pałeczkach. Sam pilot działa bez problemu wszystko w jednym i selfie i stojak. Nic już nie stoi na przeszkodzie aby robić podczas wycieczek fajne fotki z każdej perspektywy dzięki stojakowi :) Polecam'),
#  ('stojak',
#   'stojaka',
#   'Super fajny selfie stick. Rączka stojakowa rozkłada się banalnie a składa się na zasadzie magnesu który jest od dołu w pałeczkach. Sam pilot działa bez problemu wszystko w jednym i selfie i stojak. Nic już nie stoi na przeszkodzie aby robić podczas wycieczek fajne fotki z każdej perspektywy dzięki stojakowi :) Polecam'),
#  ('stojak',
#   'stojaki',
#   'Super fajny selfie stick. Rączka stojakowa rozkłada się banalnie a składa się na zasadzie magnesu który jest od dołu w pałeczkach. Sam pilot działa bez problemu wszystko w jednym i selfie i stojak. Nic już nie stoi na przeszkodzie aby robić podczas wycieczek fajne fotki z każdej perspektywy dzięki stojakowi :) Polecam'),
#  ('metalowy',
#   'metalowa',
#   'Telefon bardzo fajny jeśli ktoś lubi Windowsa Mobile. Teraz już nie do dostania w sieciach gsm. Szkoda, że ma plastikową obudowę, lepsza by była metalowa. Aparat robi bardzo dobre zdjęcia, niestety nie ma funkcji zdjęć w serii jak 535. Odrobinę powoli się ładują aplikacje, ale nie jest to już najnowszy model więc chyba nie ma co więcej oczekiwać. Generalnie, za tą cenę, jeśli ktoś poszukuje Win to telefon warty polecenia.'),
#  ('generalnie',
#   'ogół',
#   'Telefon bardzo fajny jeśli ktoś lubi Windowsa Mobile. Teraz już nie do dostania w sieciach gsm. Szkoda, że ma plastikową obudowę, lepsza by była metalowa. Aparat robi bardzo dobre zdjęcia, niestety nie ma funkcji zdjęć w serii jak 535. Odrobinę powoli się ładują aplikacje, ale nie jest to już najnowszy model więc chyba nie ma co więcej oczekiwać. Generalnie, za tą cenę, jeśli ktoś poszukuje Win to telefon warty polecenia.'),
#  ('5zł',
#   'złoty',
#   'Produkt całkiem przyzwoity jeśli chodzi o cenę 5zł, jedyna wadę jaką stwierdziłem, to brak stabilności, trzęsie nim jak galaretą, więc trzeba telefon podpierać o deskę rozdzielczą aby uniknąć drgań. Telefon mocuje się w poziomie, teoretycznie można obrócić w pionie, ale nie ma podtrzymania, więc od drgań w czasie jazy może się wysunąć i wypaść.'),
#  ('jedynać',
#   'jedyny',
#   'Produkt całkiem przyzwoity jeśli chodzi o cenę 5zł, jedyna wadę jaką stwierdziłem, to brak stabilności, trzęsie nim jak galaretą, więc trzeba telefon podpierać o deskę rozdzielczą aby uniknąć drgań. Telefon mocuje się w poziomie, teoretycznie można obrócić w pionie, ale nie ma podtrzymania, więc od drgań w czasie jazy może się wysunąć i wypaść.'),
#  ('drganie',
#   'drgań',
#   'Produkt całkiem przyzwoity jeśli chodzi o cenę 5zł, jedyna wadę jaką stwierdziłem, to brak stabilności, trzęsie nim jak galaretą, więc trzeba telefon podpierać o deskę rozdzielczą aby uniknąć drgań. Telefon mocuje się w poziomie, teoretycznie można obrócić w pionie, ale nie ma podtrzymania, więc od drgań w czasie jazy może się wysunąć i wypaść.'),
#  ('super',
#   'super.solidny',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('solidny',
#   'wieszak',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('wieszak',
#   'telefon.inny',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('telefon',
#   'plastik',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('plastik',
#   'wpływ',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('wpływ',
#   'wibracja',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('wibracja',
#   'odpadał',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('odpadał',
#   'pękać',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('pękać',
#   'miejsce',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('miejsce',
#   'znajdować',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('znajdować',
#   'sprężyna',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('sprężynka',
#   'system',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('system',
#   'solidniejszy.przyssawka',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('solidniejszy',
#   'stabilna.zatrzaska',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('przyssawka',
#   'mocne.wykonanie',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('stabilny',
#   'naprawdę',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('zatrzaski',
#   'wart',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('mocny',
#   'ceny.jeżdżę',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('wykonać',
#   '600',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('naprawde',
#   'kilometr',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('wart',
#   'dziennie',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('cena',
#   'różnoraki',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('jeżdżę',
#   'drodze.przy',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('600',
#   'wibracja',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('kilometr',
#   'auto',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('dziennie',
#   'znosi.to',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('różnoraki',
#   'wielki',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('droga',
#   'żądzy',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('wibracje',
#   'mocowanie',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('auto',
#   'wisieć',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('znosić',
#   'nie',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('wielki',
#   'luz',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('szacun',
#   'pola',
#   'Super..solidny wieszak na telefon..inne plastiki pod wpływem wibracji odpadały i pękały w miejscu gdzie znajdowała sie sprężynka, tutaj system jest solidniejszy..przyssawka stabilna..zatrzaski mocne..wykonanie naprawde warte tej ceny..jeżdżę po 600km dziennie po różnorakiej drodze..przy takich wibracjach jakie auto znosi..to wielki szacun dla tego mocowania ze jeszcze wisi i nie ma żadnych luzów.. POLECAM'),
#  ('ms',
#   'mś',
#   '"Bez ""szału"", aczkolwiek w tej cenie 24"" o tak dużej jasności, 75 Hz, czasie odpowiedzi 1 ms, matowej matrycy, ponadprzeciętnym pokryciu palet w dodatku z freesync to świetna okazja. W dodatku boczne i górne ramki bardzo wąskie, intuicyjne sterowanie. Do matrycy dość mocno lgnie kurz i sprawia wrażenie martwych pikseli, jednak ekran jest w pełni zdrowy. Z minusów - mój egzemplarz miał delikatnie przekoszony słupek mocujący, przez co po założeniu monitora na stojak zdaje się on być lekko skręcony. Dodatkowo brak regulacji wysokości i dolna ramka wyglądająca, jakby odchodziła od ekranu. Za 640 złotych chyba lepiej się nie da."'),
#  ('piksel',
#   'piksela',
#   '"Bez ""szału"", aczkolwiek w tej cenie 24"" o tak dużej jasności, 75 Hz, czasie odpowiedzi 1 ms, matowej matrycy, ponadprzeciętnym pokryciu palet w dodatku z freesync to świetna okazja. W dodatku boczne i górne ramki bardzo wąskie, intuicyjne sterowanie. Do matrycy dość mocno lgnie kurz i sprawia wrażenie martwych pikseli, jednak ekran jest w pełni zdrowy. Z minusów - mój egzemplarz miał delikatnie przekoszony słupek mocujący, przez co po założeniu monitora na stojak zdaje się on być lekko skręcony. Dodatkowo brak regulacji wysokości i dolna ramka wyglądająca, jakby odchodziła od ekranu. Za 640 złotych chyba lepiej się nie da."'),
#  ('przekoszony',
#   'przenoszyć',
#   '"Bez ""szału"", aczkolwiek w tej cenie 24"" o tak dużej jasności, 75 Hz, czasie odpowiedzi 1 ms, matowej matrycy, ponadprzeciętnym pokryciu palet w dodatku z freesync to świetna okazja. W dodatku boczne i górne ramki bardzo wąskie, intuicyjne sterowanie. Do matrycy dość mocno lgnie kurz i sprawia wrażenie martwych pikseli, jednak ekran jest w pełni zdrowy. Z minusów - mój egzemplarz miał delikatnie przekoszony słupek mocujący, przez co po założeniu monitora na stojak zdaje się on być lekko skręcony. Dodatkowo brak regulacji wysokości i dolna ramka wyglądająca, jakby odchodziła od ekranu. Za 640 złotych chyba lepiej się nie da."'),
#  ('mocuć',
#   'mocujący',
#   '"Bez ""szału"", aczkolwiek w tej cenie 24"" o tak dużej jasności, 75 Hz, czasie odpowiedzi 1 ms, matowej matrycy, ponadprzeciętnym pokryciu palet w dodatku z freesync to świetna okazja. W dodatku boczne i górne ramki bardzo wąskie, intuicyjne sterowanie. Do matrycy dość mocno lgnie kurz i sprawia wrażenie martwych pikseli, jednak ekran jest w pełni zdrowy. Z minusów - mój egzemplarz miał delikatnie przekoszony słupek mocujący, przez co po założeniu monitora na stojak zdaje się on być lekko skręcony. Dodatkowo brak regulacji wysokości i dolna ramka wyglądająca, jakby odchodziła od ekranu. Za 640 złotych chyba lepiej się nie da."'),
#  ('skręcyć',
#   'skręcony',
#   '"Bez ""szału"", aczkolwiek w tej cenie 24"" o tak dużej jasności, 75 Hz, czasie odpowiedzi 1 ms, matowej matrycy, ponadprzeciętnym pokryciu palet w dodatku z freesync to świetna okazja. W dodatku boczne i górne ramki bardzo wąskie, intuicyjne sterowanie. Do matrycy dość mocno lgnie kurz i sprawia wrażenie martwych pikseli, jednak ekran jest w pełni zdrowy. Z minusów - mój egzemplarz miał delikatnie przekoszony słupek mocujący, przez co po założeniu monitora na stojak zdaje się on być lekko skręcony. Dodatkowo brak regulacji wysokości i dolna ramka wyglądająca, jakby odchodziła od ekranu. Za 640 złotych chyba lepiej się nie da."'),
#  ('wyglądający',
#   'wyglądająca',
#   '"Bez ""szału"", aczkolwiek w tej cenie 24"" o tak dużej jasności, 75 Hz, czasie odpowiedzi 1 ms, matowej matrycy, ponadprzeciętnym pokryciu palet w dodatku z freesync to świetna okazja. W dodatku boczne i górne ramki bardzo wąskie, intuicyjne sterowanie. Do matrycy dość mocno lgnie kurz i sprawia wrażenie martwych pikseli, jednak ekran jest w pełni zdrowy. Z minusów - mój egzemplarz miał delikatnie przekoszony słupek mocujący, przez co po założeniu monitora na stojak zdaje się on być lekko skręcony. Dodatkowo brak regulacji wysokości i dolna ramka wyglądająca, jakby odchodziła od ekranu. Za 640 złotych chyba lepiej się nie da."'),
#  ('dać',
#   'da',
#   '"Bez ""szału"", aczkolwiek w tej cenie 24"" o tak dużej jasności, 75 Hz, czasie odpowiedzi 1 ms, matowej matrycy, ponadprzeciętnym pokryciu palet w dodatku z freesync to świetna okazja. W dodatku boczne i górne ramki bardzo wąskie, intuicyjne sterowanie. Do matrycy dość mocno lgnie kurz i sprawia wrażenie martwych pikseli, jednak ekran jest w pełni zdrowy. Z minusów - mój egzemplarz miał delikatnie przekoszony słupek mocujący, przez co po założeniu monitora na stojak zdaje się on być lekko skręcony. Dodatkowo brak regulacji wysokości i dolna ramka wyglądająca, jakby odchodziła od ekranu. Za 640 złotych chyba lepiej się nie da."'),
#  ('szerszy',
#   'szersza',
#   '"Sprzęt jest OK - górną półką toto nie jest, jednak stosunek ceny do możliwości jest bardziej niż zadowalający. Do jakości wykonania nie można się doczepić. Telefon jest mniejszy, niż się spodziewałem, krótszy niż typowy telefon 5"", choć odrobinę szerszy. Trzeba się przyzwyczaić do selfie-aparatu u dołu ekranu, łapie człowieka z nietypowej perspektywy: wyglądam jakby natchniony, bo patrząc w ekran wyglądam jakbym spoglądał w niebo ;) Poza tym nietypowe położenie sprzętowych przycisków - po lewej. I fabrycznie androidowy klawisz ""cofnij"" (trójkąt) wyświetla się po prawej, a kwadrat po lewej, ale to da się zmienić w ustawieniach. Po prostu wszystko trochę na opak, zmusza do zastanowienia się zanim się coś zrobi."'),
#  ('natchniyć',
#   'natchniony',
#   '"Sprzęt jest OK - górną półką toto nie jest, jednak stosunek ceny do możliwości jest bardziej niż zadowalający. Do jakości wykonania nie można się doczepić. Telefon jest mniejszy, niż się spodziewałem, krótszy niż typowy telefon 5"", choć odrobinę szerszy. Trzeba się przyzwyczaić do selfie-aparatu u dołu ekranu, łapie człowieka z nietypowej perspektywy: wyglądam jakby natchniony, bo patrząc w ekran wyglądam jakbym spoglądał w niebo ;) Poza tym nietypowe położenie sprzętowych przycisków - po lewej. I fabrycznie androidowy klawisz ""cofnij"" (trójkąt) wyświetla się po prawej, a kwadrat po lewej, ale to da się zmienić w ustawieniach. Po prostu wszystko trochę na opak, zmusza do zastanowienia się zanim się coś zrobi."'),
#  ('lewy',
#   'lewa',
#   '"Sprzęt jest OK - górną półką toto nie jest, jednak stosunek ceny do możliwości jest bardziej niż zadowalający. Do jakości wykonania nie można się doczepić. Telefon jest mniejszy, niż się spodziewałem, krótszy niż typowy telefon 5"", choć odrobinę szerszy. Trzeba się przyzwyczaić do selfie-aparatu u dołu ekranu, łapie człowieka z nietypowej perspektywy: wyglądam jakby natchniony, bo patrząc w ekran wyglądam jakbym spoglądał w niebo ;) Poza tym nietypowe położenie sprzętowych przycisków - po lewej. I fabrycznie androidowy klawisz ""cofnij"" (trójkąt) wyświetla się po prawej, a kwadrat po lewej, ale to da się zmienić w ustawieniach. Po prostu wszystko trochę na opak, zmusza do zastanowienia się zanim się coś zrobi."'),
#  ('androidowy',
#   'android',
#   '"Sprzęt jest OK - górną półką toto nie jest, jednak stosunek ceny do możliwości jest bardziej niż zadowalający. Do jakości wykonania nie można się doczepić. Telefon jest mniejszy, niż się spodziewałem, krótszy niż typowy telefon 5"", choć odrobinę szerszy. Trzeba się przyzwyczaić do selfie-aparatu u dołu ekranu, łapie człowieka z nietypowej perspektywy: wyglądam jakby natchniony, bo patrząc w ekran wyglądam jakbym spoglądał w niebo ;) Poza tym nietypowe położenie sprzętowych przycisków - po lewej. I fabrycznie androidowy klawisz ""cofnij"" (trójkąt) wyświetla się po prawej, a kwadrat po lewej, ale to da się zmienić w ustawieniach. Po prostu wszystko trochę na opak, zmusza do zastanowienia się zanim się coś zrobi."'),
#  ('ustawienie',
#   'ustawienii',
#   '"Sprzęt jest OK - górną półką toto nie jest, jednak stosunek ceny do możliwości jest bardziej niż zadowalający. Do jakości wykonania nie można się doczepić. Telefon jest mniejszy, niż się spodziewałem, krótszy niż typowy telefon 5"", choć odrobinę szerszy. Trzeba się przyzwyczaić do selfie-aparatu u dołu ekranu, łapie człowieka z nietypowej perspektywy: wyglądam jakby natchniony, bo patrząc w ekran wyglądam jakbym spoglądał w niebo ;) Poza tym nietypowe położenie sprzętowych przycisków - po lewej. I fabrycznie androidowy klawisz ""cofnij"" (trójkąt) wyświetla się po prawej, a kwadrat po lewej, ale to da się zmienić w ustawieniach. Po prostu wszystko trochę na opak, zmusza do zastanowienia się zanim się coś zrobi."'),
#  ('klejący',
#   'kleć',
#   'Produkt może i wygląda futurystycznie i całkiem ciekawie ale... Brak zakrzywionych uchwytów do trzymania telefonu w poziomie, telefon trzyma się tylko na ścisk szczęk. Przyssawka zepsuła się po 1 oderwaniu od szyby. Niby trzyma się dzięki klejącemu się materiałowi z którego jest zrobiona, ale zatrzask dociskający ją już nie działa. Może trafiłem taki egzemplarz a może wszystkie takie są,'),
#  ('youtuba',
#   'youtube',
#   'Nie lubię smartfonów, a równocześnie potrzebuję czasem skorzystać z internetu, youtuba czy google maps ;) Wady: Brak FaceBook, brak softu do zarządzania pod Win, tylko kilka aplikacji w KaiOS store, karty SIM Micro i Nano (nie da się zwykłej MiniSIM), brak narzędzi i informacji technicznych o telefonie - sam bym pokompilował i pokonfigurował, gdyby była dokumentacja, plastik kiepskiej jakości, Wifi b/g/n bez ac, Nie ma HDVoice, toporny wygląd menu, aparat tylko 2mpix'),
#  ('maps',
#   'mapa',
#   'Nie lubię smartfonów, a równocześnie potrzebuję czasem skorzystać z internetu, youtuba czy google maps ;) Wady: Brak FaceBook, brak softu do zarządzania pod Win, tylko kilka aplikacji w KaiOS store, karty SIM Micro i Nano (nie da się zwykłej MiniSIM), brak narzędzi i informacji technicznych o telefonie - sam bym pokompilował i pokonfigurował, gdyby była dokumentacja, plastik kiepskiej jakości, Wifi b/g/n bez ac, Nie ma HDVoice, toporny wygląd menu, aparat tylko 2mpix'),
#  ('kaios',
#   'kaja',
#   'Nie lubię smartfonów, a równocześnie potrzebuję czasem skorzystać z internetu, youtuba czy google maps ;) Wady: Brak FaceBook, brak softu do zarządzania pod Win, tylko kilka aplikacji w KaiOS store, karty SIM Micro i Nano (nie da się zwykłej MiniSIM), brak narzędzi i informacji technicznych o telefonie - sam bym pokompilował i pokonfigurował, gdyby była dokumentacja, plastik kiepskiej jakości, Wifi b/g/n bez ac, Nie ma HDVoice, toporny wygląd menu, aparat tylko 2mpix'),
#  ('story',
#   'stora',
#   'Nie lubię smartfonów, a równocześnie potrzebuję czasem skorzystać z internetu, youtuba czy google maps ;) Wady: Brak FaceBook, brak softu do zarządzania pod Win, tylko kilka aplikacji w KaiOS store, karty SIM Micro i Nano (nie da się zwykłej MiniSIM), brak narzędzi i informacji technicznych o telefonie - sam bym pokompilował i pokonfigurował, gdyby była dokumentacja, plastik kiepskiej jakości, Wifi b/g/n bez ac, Nie ma HDVoice, toporny wygląd menu, aparat tylko 2mpix'),
#  ('sim',
#   'micro',
#   'Nie lubię smartfonów, a równocześnie potrzebuję czasem skorzystać z internetu, youtuba czy google maps ;) Wady: Brak FaceBook, brak softu do zarządzania pod Win, tylko kilka aplikacji w KaiOS store, karty SIM Micro i Nano (nie da się zwykłej MiniSIM), brak narzędzi i informacji technicznych o telefonie - sam bym pokompilował i pokonfigurował, gdyby była dokumentacja, plastik kiepskiej jakości, Wifi b/g/n bez ac, Nie ma HDVoice, toporny wygląd menu, aparat tylko 2mpix'),
#  ('micro',
#   'nato',
#   'Nie lubię smartfonów, a równocześnie potrzebuję czasem skorzystać z internetu, youtuba czy google maps ;) Wady: Brak FaceBook, brak softu do zarządzania pod Win, tylko kilka aplikacji w KaiOS store, karty SIM Micro i Nano (nie da się zwykłej MiniSIM), brak narzędzi i informacji technicznych o telefonie - sam bym pokompilował i pokonfigurował, gdyby była dokumentacja, plastik kiepskiej jakości, Wifi b/g/n bez ac, Nie ma HDVoice, toporny wygląd menu, aparat tylko 2mpix'),
#  ('nano',
#   'nie',
#   'Nie lubię smartfonów, a równocześnie potrzebuję czasem skorzystać z internetu, youtuba czy google maps ;) Wady: Brak FaceBook, brak softu do zarządzania pod Win, tylko kilka aplikacji w KaiOS store, karty SIM Micro i Nano (nie da się zwykłej MiniSIM), brak narzędzi i informacji technicznych o telefonie - sam bym pokompilował i pokonfigurował, gdyby była dokumentacja, plastik kiepskiej jakości, Wifi b/g/n bez ac, Nie ma HDVoice, toporny wygląd menu, aparat tylko 2mpix'),
#  ('nie',
#   'dać',
#   'Nie lubię smartfonów, a równocześnie potrzebuję czasem skorzystać z internetu, youtuba czy google maps ;) Wady: Brak FaceBook, brak softu do zarządzania pod Win, tylko kilka aplikacji w KaiOS store, karty SIM Micro i Nano (nie da się zwykłej MiniSIM), brak narzędzi i informacji technicznych o telefonie - sam bym pokompilował i pokonfigurował, gdyby była dokumentacja, plastik kiepskiej jakości, Wifi b/g/n bez ac, Nie ma HDVoice, toporny wygląd menu, aparat tylko 2mpix'),
#  ('dać',
#   'zwykły',
#   'Nie lubię smartfonów, a równocześnie potrzebuję czasem skorzystać z internetu, youtuba czy google maps ;) Wady: Brak FaceBook, brak softu do zarządzania pod Win, tylko kilka aplikacji w KaiOS store, karty SIM Micro i Nano (nie da się zwykłej MiniSIM), brak narzędzi i informacji technicznych o telefonie - sam bym pokompilował i pokonfigurował, gdyby była dokumentacja, plastik kiepskiej jakości, Wifi b/g/n bez ac, Nie ma HDVoice, toporny wygląd menu, aparat tylko 2mpix'),
#  ('zwykły',
#   'minisi',
# ...
#  ('maksymalć',
#   'środek',
#   '"Plecak jest zrobiony z dobrych materiałów i ma dużo przydatnych kieszeni, w których można poupychać różne drobiazgi. Jest całkiem wysoki więc nie będzie rówież poblemu z włożeniem do środka klawiatury lub dwóch ;) Co do rozmiaru to maksymalnie do środka wejdzie laptop o przekątnej 15,6 cala. Warto również brać pod uwagę, że plecak ma jeden pasek typu kołczan, przez co jeżeli ma się cięższy ""gamingowy"" sprzęt (o czym przekonałem się na własnej skórze) po pewnym czasie może zacząć boleć jedno ramię (jako, że ciężar nie jest równomiernie rozłożony). Poza tym jednak produkt godny polecenia, zwłaszcza ze względu na jakość wykonania, rozmiar, oburęczność (tudzież ""oburamioność"" w tym przypadku) i, a zwłaszcza, cenę. Serdecznie polecam."'),
#  ('środek',
#   'wejść',
#   '"Plecak jest zrobiony z dobrych materiałów i ma dużo przydatnych kieszeni, w których można poupychać różne drobiazgi. Jest całkiem wysoki więc nie będzie rówież poblemu z włożeniem do środka klawiatury lub dwóch ;) Co do rozmiaru to maksymalnie do środka wejdzie laptop o przekątnej 15,6 cala. Warto również brać pod uwagę, że plecak ma jeden pasek typu kołczan, przez co jeżeli ma się cięższy ""gamingowy"" sprzęt (o czym przekonałem się na własnej skórze) po pewnym czasie może zacząć boleć jedno ramię (jako, że ciężar nie jest równomiernie rozłożony). Poza tym jednak produkt godny polecenia, zwłaszcza ze względu na jakość wykonania, rozmiar, oburęczność (tudzież ""oburamioność"" w tym przypadku) i, a zwłaszcza, cenę. Serdecznie polecam."'),
#  ('wejść',
#   'laptop',
#   '"Plecak jest zrobiony z dobrych materiałów i ma dużo przydatnych kieszeni, w których można poupychać różne drobiazgi. Jest całkiem wysoki więc nie będzie rówież poblemu z włożeniem do środka klawiatury lub dwóch ;) Co do rozmiaru to maksymalnie do środka wejdzie laptop o przekątnej 15,6 cala. Warto również brać pod uwagę, że plecak ma jeden pasek typu kołczan, przez co jeżeli ma się cięższy ""gamingowy"" sprzęt (o czym przekonałem się na własnej skórze) po pewnym czasie może zacząć boleć jedno ramię (jako, że ciężar nie jest równomiernie rozłożony). Poza tym jednak produkt godny polecenia, zwłaszcza ze względu na jakość wykonania, rozmiar, oburęczność (tudzież ""oburamioność"" w tym przypadku) i, a zwłaszcza, cenę. Serdecznie polecam."'),
#  ('laptop',
#   'przekątny',
#   '"Plecak jest zrobiony z dobrych materiałów i ma dużo przydatnych kieszeni, w których można poupychać różne drobiazgi. Jest całkiem wysoki więc nie będzie rówież poblemu z włożeniem do środka klawiatury lub dwóch ;) Co do rozmiaru to maksymalnie do środka wejdzie laptop o przekątnej 15,6 cala. Warto również brać pod uwagę, że plecak ma jeden pasek typu kołczan, przez co jeżeli ma się cięższy ""gamingowy"" sprzęt (o czym przekonałem się na własnej skórze) po pewnym czasie może zacząć boleć jedno ramię (jako, że ciężar nie jest równomiernie rozłożony). Poza tym jednak produkt godny polecenia, zwłaszcza ze względu na jakość wykonania, rozmiar, oburęczność (tudzież ""oburamioność"" w tym przypadku) i, a zwłaszcza, cenę. Serdecznie polecam."'),
#  ('przekątny',
#   '15,6',
#   '"Plecak jest zrobiony z dobrych materiałów i ma dużo przydatnych kieszeni, w których można poupychać różne drobiazgi. Jest całkiem wysoki więc nie będzie rówież poblemu z włożeniem do środka klawiatury lub dwóch ;) Co do rozmiaru to maksymalnie do środka wejdzie laptop o przekątnej 15,6 cala. Warto również brać pod uwagę, że plecak ma jeden pasek typu kołczan, przez co jeżeli ma się cięższy ""gamingowy"" sprzęt (o czym przekonałem się na własnej skórze) po pewnym czasie może zacząć boleć jedno ramię (jako, że ciężar nie jest równomiernie rozłożony). Poza tym jednak produkt godny polecenia, zwłaszcza ze względu na jakość wykonania, rozmiar, oburęczność (tudzież ""oburamioność"" w tym przypadku) i, a zwłaszcza, cenę. Serdecznie polecam."'),
#  ('15,6',
#   'warto',
#   '"Plecak jest zrobiony z dobrych materiałów i ma dużo przydatnych kieszeni, w których można poupychać różne drobiazgi. Jest całkiem wysoki więc nie będzie rówież poblemu z włożeniem do środka klawiatury lub dwóch ;) Co do rozmiaru to maksymalnie do środka wejdzie laptop o przekątnej 15,6 cala. Warto również brać pod uwagę, że plecak ma jeden pasek typu kołczan, przez co jeżeli ma się cięższy ""gamingowy"" sprzęt (o czym przekonałem się na własnej skórze) po pewnym czasie może zacząć boleć jedno ramię (jako, że ciężar nie jest równomiernie rozłożony). Poza tym jednak produkt godny polecenia, zwłaszcza ze względu na jakość wykonania, rozmiar, oburęczność (tudzież ""oburamioność"" w tym przypadku) i, a zwłaszcza, cenę. Serdecznie polecam."'),
#  ('warto',
#   'brać',
#   '"Plecak jest zrobiony z dobrych materiałów i ma dużo przydatnych kieszeni, w których można poupychać różne drobiazgi. Jest całkiem wysoki więc nie będzie rówież poblemu z włożeniem do środka klawiatury lub dwóch ;) Co do rozmiaru to maksymalnie do środka wejdzie laptop o przekątnej 15,6 cala. Warto również brać pod uwagę, że plecak ma jeden pasek typu kołczan, przez co jeżeli ma się cięższy ""gamingowy"" sprzęt (o czym przekonałem się na własnej skórze) po pewnym czasie może zacząć boleć jedno ramię (jako, że ciężar nie jest równomiernie rozłożony). Poza tym jednak produkt godny polecenia, zwłaszcza ze względu na jakość wykonania, rozmiar, oburęczność (tudzież ""oburamioność"" w tym przypadku) i, a zwłaszcza, cenę. Serdecznie polecam."'),
#  ('brać',
#   'uwaga',
#   '"Plecak jest zrobiony z dobrych materiałów i ma dużo przydatnych kieszeni, w których można poupychać różne drobiazgi. Jest całkiem wysoki więc nie będzie rówież poblemu z włożeniem do środka klawiatury lub dwóch ;) Co do rozmiaru to maksymalnie do środka wejdzie laptop o przekątnej 15,6 cala. Warto również brać pod uwagę, że plecak ma jeden pasek typu kołczan, przez co jeżeli ma się cięższy ""gamingowy"" sprzęt (o czym przekonałem się na własnej skórze) po pewnym czasie może zacząć boleć jedno ramię (jako, że ciężar nie jest równomiernie rozłożony). Poza tym jednak produkt godny polecenia, zwłaszcza ze względu na jakość wykonania, rozmiar, oburęczność (tudzież ""oburamioność"" w tym przypadku) i, a zwłaszcza, cenę. Serdecznie polecam."'),
#  ('uwaga',
#   'plecak',
#   '"Plecak jest zrobiony z dobrych materiałów i ma dużo przydatnych kieszeni, w których można poupychać różne drobiazgi. Jest całkiem wysoki więc nie będzie rówież poblemu z włożeniem do środka klawiatury lub dwóch ;) Co do rozmiaru to maksymalnie do środka wejdzie laptop o przekątnej 15,6 cala. Warto również brać pod uwagę, że plecak ma jeden pasek typu kołczan, przez co jeżeli ma się cięższy ""gamingowy"" sprzęt (o czym przekonałem się na własnej skórze) po pewnym czasie może zacząć boleć jedno ramię (jako, że ciężar nie jest równomiernie rozłożony). Poza tym jednak produkt godny polecenia, zwłaszcza ze względu na jakość wykonania, rozmiar, oburęczność (tudzież ""oburamioność"" w tym przypadku) i, a zwłaszcza, cenę. Serdecznie polecam."'),
#  ('plecak',
#   'pasek',
#   '"Plecak jest zrobiony z dobrych materiałów i ma dużo przydatnych kieszeni, w których można poupychać różne drobiazgi. Jest całkiem wysoki więc nie będzie rówież poblemu z włożeniem do środka klawiatury lub dwóch ;) Co do rozmiaru to maksymalnie do środka wejdzie laptop o przekątnej 15,6 cala. Warto również brać pod uwagę, że plecak ma jeden pasek typu kołczan, przez co jeżeli ma się cięższy ""gamingowy"" sprzęt (o czym przekonałem się na własnej skórze) po pewnym czasie może zacząć boleć jedno ramię (jako, że ciężar nie jest równomiernie rozłożony). Poza tym jednak produkt godny polecenia, zwłaszcza ze względu na jakość wykonania, rozmiar, oburęczność (tudzież ""oburamioność"" w tym przypadku) i, a zwłaszcza, cenę. Serdecznie polecam."'),
#  ('pasek',
#   'typ',
#   '"Plecak jest zrobiony z dobrych materiałów i ma dużo przydatnych kieszeni, w których można poupychać różne drobiazgi. Jest całkiem wysoki więc nie będzie rówież poblemu z włożeniem do środka klawiatury lub dwóch ;) Co do rozmiaru to maksymalnie do środka wejdzie laptop o przekątnej 15,6 cala. Warto również brać pod uwagę, że plecak ma jeden pasek typu kołczan, przez co jeżeli ma się cięższy ""gamingowy"" sprzęt (o czym przekonałem się na własnej skórze) po pewnym czasie może zacząć boleć jedno ramię (jako, że ciężar nie jest równomiernie rozłożony). Poza tym jednak produkt godny polecenia, zwłaszcza ze względu na jakość wykonania, rozmiar, oburęczność (tudzież ""oburamioność"" w tym przypadku) i, a zwłaszcza, cenę. Serdecznie polecam."'),
#  ('typ',
#   'kołczan',
#   '"Plecak jest zrobiony z dobrych materiałów i ma dużo przydatnych kieszeni, w których można poupychać różne drobiazgi. Jest całkiem wysoki więc nie będzie rówież poblemu z włożeniem do środka klawiatury lub dwóch ;) Co do rozmiaru to maksymalnie do środka wejdzie laptop o przekątnej 15,6 cala. Warto również brać pod uwagę, że plecak ma jeden pasek typu kołczan, przez co jeżeli ma się cięższy ""gamingowy"" sprzęt (o czym przekonałem się na własnej skórze) po pewnym czasie może zacząć boleć jedno ramię (jako, że ciężar nie jest równomiernie rozłożony). Poza tym jednak produkt godny polecenia, zwłaszcza ze względu na jakość wykonania, rozmiar, oburęczność (tudzież ""oburamioność"" w tym przypadku) i, a zwłaszcza, cenę. Serdecznie polecam."'),
#  ('kołczan',
#   'cięższy',
#   '"Plecak jest zrobiony z dobrych materiałów i ma dużo przydatnych kieszeni, w których można poupychać różne drobiazgi. Jest całkiem wysoki więc nie będzie rówież poblemu z włożeniem do środka klawiatury lub dwóch ;) Co do rozmiaru to maksymalnie do środka wejdzie laptop o przekątnej 15,6 cala. Warto również brać pod uwagę, że plecak ma jeden pasek typu kołczan, przez co jeżeli ma się cięższy ""gamingowy"" sprzęt (o czym przekonałem się na własnej skórze) po pewnym czasie może zacząć boleć jedno ramię (jako, że ciężar nie jest równomiernie rozłożony). Poza tym jednak produkt godny polecenia, zwłaszcza ze względu na jakość wykonania, rozmiar, oburęczność (tudzież ""oburamioność"" w tym przypadku) i, a zwłaszcza, cenę. Serdecznie polecam."'),
#  ('cięższy',
#   'gamingowy',
#   '"Plecak jest zrobiony z dobrych materiałów i ma dużo przydatnych kieszeni, w których można poupychać różne drobiazgi. Jest całkiem wysoki więc nie będzie rówież poblemu z włożeniem do środka klawiatury lub dwóch ;) Co do rozmiaru to maksymalnie do środka wejdzie laptop o przekątnej 15,6 cala. Warto również brać pod uwagę, że plecak ma jeden pasek typu kołczan, przez co jeżeli ma się cięższy ""gamingowy"" sprzęt (o czym przekonałem się na własnej skórze) po pewnym czasie może zacząć boleć jedno ramię (jako, że ciężar nie jest równomiernie rozłożony). Poza tym jednak produkt godny polecenia, zwłaszcza ze względu na jakość wykonania, rozmiar, oburęczność (tudzież ""oburamioność"" w tym przypadku) i, a zwłaszcza, cenę. Serdecznie polecam."'),
#  ('gamingowy',
#   'sprzęt',
#   '"Plecak jest zrobiony z dobrych materiałów i ma dużo przydatnych kieszeni, w których można poupychać różne drobiazgi. Jest całkiem wysoki więc nie będzie rówież poblemu z włożeniem do środka klawiatury lub dwóch ;) Co do rozmiaru to maksymalnie do środka wejdzie laptop o przekątnej 15,6 cala. Warto również brać pod uwagę, że plecak ma jeden pasek typu kołczan, przez co jeżeli ma się cięższy ""gamingowy"" sprzęt (o czym przekonałem się na własnej skórze) po pewnym czasie może zacząć boleć jedno ramię (jako, że ciężar nie jest równomiernie rozłożony). Poza tym jednak produkt godny polecenia, zwłaszcza ze względu na jakość wykonania, rozmiar, oburęczność (tudzież ""oburamioność"" w tym przypadku) i, a zwłaszcza, cenę. Serdecznie polecam."'),
#  ('sprzęt',
#   'co',
#   '"Plecak jest zrobiony z dobrych materiałów i ma dużo przydatnych kieszeni, w których można poupychać różne drobiazgi. Jest całkiem wysoki więc nie będzie rówież poblemu z włożeniem do środka klawiatury lub dwóch ;) Co do rozmiaru to maksymalnie do środka wejdzie laptop o przekątnej 15,6 cala. Warto również brać pod uwagę, że plecak ma jeden pasek typu kołczan, przez co jeżeli ma się cięższy ""gamingowy"" sprzęt (o czym przekonałem się na własnej skórze) po pewnym czasie może zacząć boleć jedno ramię (jako, że ciężar nie jest równomiernie rozłożony). Poza tym jednak produkt godny polecenia, zwłaszcza ze względu na jakość wykonania, rozmiar, oburęczność (tudzież ""oburamioność"" w tym przypadku) i, a zwłaszcza, cenę. Serdecznie polecam."'),
#  ('co',
#   'przekonać być',
#   '"Plecak jest zrobiony z dobrych materiałów i ma dużo przydatnych kieszeni, w których można poupychać różne drobiazgi. Jest całkiem wysoki więc nie będzie rówież poblemu z włożeniem do środka klawiatury lub dwóch ;) Co do rozmiaru to maksymalnie do środka wejdzie laptop o przekątnej 15,6 cala. Warto również brać pod uwagę, że plecak ma jeden pasek typu kołczan, przez co jeżeli ma się cięższy ""gamingowy"" sprzęt (o czym przekonałem się na własnej skórze) po pewnym czasie może zacząć boleć jedno ramię (jako, że ciężar nie jest równomiernie rozłożony). Poza tym jednak produkt godny polecenia, zwłaszcza ze względu na jakość wykonania, rozmiar, oburęczność (tudzież ""oburamioność"" w tym przypadku) i, a zwłaszcza, cenę. Serdecznie polecam."'),
#  ('przekonać być',
#   'własny',
#   '"Plecak jest zrobiony z dobrych materiałów i ma dużo przydatnych kieszeni, w których można poupychać różne drobiazgi. Jest całkiem wysoki więc nie będzie rówież poblemu z włożeniem do środka klawiatury lub dwóch ;) Co do rozmiaru to maksymalnie do środka wejdzie laptop o przekątnej 15,6 cala. Warto również brać pod uwagę, że plecak ma jeden pasek typu kołczan, przez co jeżeli ma się cięższy ""gamingowy"" sprzęt (o czym przekonałem się na własnej skórze) po pewnym czasie może zacząć boleć jedno ramię (jako, że ciężar nie jest równomiernie rozłożony). Poza tym jednak produkt godny polecenia, zwłaszcza ze względu na jakość wykonania, rozmiar, oburęczność (tudzież ""oburamioność"" w tym przypadku) i, a zwłaszcza, cenę. Serdecznie polecam."'),
#  ('własny',
#   'skóra',
#   '"Plecak jest zrobiony z dobrych materiałów i ma dużo przydatnych kieszeni, w których można poupychać różne drobiazgi. Jest całkiem wysoki więc nie będzie rówież poblemu z włożeniem do środka klawiatury lub dwóch ;) Co do rozmiaru to maksymalnie do środka wejdzie laptop o przekątnej 15,6 cala. Warto również brać pod uwagę, że plecak ma jeden pasek typu kołczan, przez co jeżeli ma się cięższy ""gamingowy"" sprzęt (o czym przekonałem się na własnej skórze) po pewnym czasie może zacząć boleć jedno ramię (jako, że ciężar nie jest równomiernie rozłożony). Poza tym jednak produkt godny polecenia, zwłaszcza ze względu na jakość wykonania, rozmiar, oburęczność (tudzież ""oburamioność"" w tym przypadku) i, a zwłaszcza, cenę. Serdecznie polecam."'),
#  ('skóra',
#   'pewien',
#   '"Plecak jest zrobiony z dobrych materiałów i ma dużo przydatnych kieszeni, w których można poupychać różne drobiazgi. Jest całkiem wysoki więc nie będzie rówież poblemu z włożeniem do środka klawiatury lub dwóch ;) Co do rozmiaru to maksymalnie do środka wejdzie laptop o przekątnej 15,6 cala. Warto również brać pod uwagę, że plecak ma jeden pasek typu kołczan, przez co jeżeli ma się cięższy ""gamingowy"" sprzęt (o czym przekonałem się na własnej skórze) po pewnym czasie może zacząć boleć jedno ramię (jako, że ciężar nie jest równomiernie rozłożony). Poza tym jednak produkt godny polecenia, zwłaszcza ze względu na jakość wykonania, rozmiar, oburęczność (tudzież ""oburamioność"" w tym przypadku) i, a zwłaszcza, cenę. Serdecznie polecam."'),
#  ...]

# %%
# Out:
# False
